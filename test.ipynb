# %%
! pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.9 MB 4.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.9 MB 3.5 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/9.9 MB 3.9 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/9.9 MB 4.1 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.9 MB 4.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/9.9 MB 4.3 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/9.9 MB 4.4 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/9.9 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.9 MB 4.3 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 4.2 MB/s eta 0:00:01
# ...

# %%
#Working with pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df
# Out:
#    name  address   age
# 0  hari      ktm    10
# 1  saru      bkt    12

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    name  address   age
# 0  hari      ktm    10
# 1  saru      bkt    12

# %%
df.head()
# Out:
# <bound method NDFrame.head of    name  address   age
# 0  hari      ktm    10
# 1  saru      bkt    12>

# %%
df.sample()
# Out:
#    name  address   age
# 1  saru      bkt    12

# %%
df['name']=='saru'
# Out:
# 0    False
# 1     True
# Name: name, dtype: bool
